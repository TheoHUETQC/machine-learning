# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from seaborn import heatmap

# load data
df = pd.read_csv('https://docs.google.com/spreadsheets/d/e/2PACX-1vTRfoQAojPwNsw33zUSpBg32DuK2z0WvLPptGOncIXa38tN3RWk9puvelcmsIIhFb_XF12RD7PdqCwf/pub?output=csv')

# %%
print("Nan :\n",df.isna().sum())
print("\n")
print("duplicated ? ",df.duplicated().any())
# Out:
# Nan :
#  Age               0
# Sex               0
# ChestPainType     0
# RestingBP         0
# Cholesterol       0
# FastingBS         0
# RestingECG        0
# MaxHR             0
# ExerciseAngina    0
# Oldpeak           0
# ST_Slope          0
# HeartDisease      0
# dtype: int64
#
#
# duplicated ?  False

# %%
df
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0      172              N      0.0       Up             0
# 1      156              N      1.0     Flat             1
# 2       98              N      0.0       Up             0
# 3      108              Y      1.5     Flat             1
# 4      122              N      0.0       Up             0
# ..     ...            ...      ...      ...           ...
# 913    132              N      1.2     Flat             1
# 914    141              N      3.4     Flat             1
# 915    115              Y      1.2     Flat             1
# 916    174              N      0.0     Flat             1
# 917    173              N      0.0       Up             0
#
# [918 rows x 12 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 918 entries, 0 to 917
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             918 non-null    int64
#  1   Sex             918 non-null    object
#  2   ChestPainType   918 non-null    object
#  3   RestingBP       918 non-null    int64
#  4   Cholesterol     918 non-null    int64
#  5   FastingBS       918 non-null    int64
#  6   RestingECG      918 non-null    object
#  7   MaxHR           918 non-null    int64
#  8   ExerciseAngina  918 non-null    object
#  9   Oldpeak         918 non-null    float64
#  10  ST_Slope        918 non-null    object
#  11  HeartDisease    918 non-null    int64
# dtypes: float64(1), int64(6), object(5)
# memory usage: 86.2+ KB

# %%
no_Cholesterol = df['Cholesterol'] == 0
no_RestingBP = df['RestingBP'] == 0


#class_df_clean excludes rows that have no values == 0 in the above columns
class_df_clean = df[~(no_Cholesterol |
                                     no_RestingBP )]
class_df_clean.describe()
# Out:
#               Age   RestingBP  Cholesterol   FastingBS       MaxHR  \
# count  746.000000  746.000000   746.000000  746.000000  746.000000
# mean    52.882038  133.022788   244.635389    0.167560  140.226542
# std      9.505888   17.282750    59.153524    0.373726   24.524107
# min     28.000000   92.000000    85.000000    0.000000   69.000000
# 25%     46.000000  120.000000   207.250000    0.000000  122.000000
# 50%     54.000000  130.000000   237.000000    0.000000  140.000000
# 75%     59.000000  140.000000   275.000000    0.000000  160.000000
# max     77.000000  200.000000   603.000000    1.000000  202.000000
#
#           Oldpeak  HeartDisease
# count  746.000000    746.000000
# mean     0.901609      0.477212
# std      1.072861      0.499816
# min     -0.100000      0.000000
# 25%      0.000000      0.000000
# 50%      0.500000      0.000000
# 75%      1.500000      1.000000
# max      6.200000      1.000000

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.compose import make_column_selector, make_column_transformer
from sklearn.pipeline import make_pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer

## Define X and y
target = 'HeartDisease'

X = class_df_clean.drop(columns=target).copy()
y = class_df_clean[target].copy()

# Perfoming a train-test-split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 42)

# Defining a list of features for both the categorical and the numerical columns

cat_feature = make_column_selector(dtype_include='object')   # Creating a categorical data selector
num_feature = make_column_selector(dtype_include='number')   # Creating a numeric data selector

# Instantiating the Transformers

impute_cat = SimpleImputer(strategy='most_frequent') #better to keep the ffil but for simplicity reasons I will keep this one
impute_num = SimpleImputer(strategy='median') # we can be more sophisticated and make a mean imputation for widht like we did earlier, but I'll keep it simple for now
ohe_encoder = OneHotEncoder(sparse_output=False, handle_unknown='ignore')   # It is a numinal column with no order to it => So I used the One-hot encoding
scaler = StandardScaler()

# Making pipelines for each category

pip_cat = make_pipeline(impute_cat, ohe_encoder)
pip_num = make_pipeline(impute_num, scaler)

# Defining a tuple for each pathway

categorical_tup = ('Categorical', pip_cat, cat_feature)
numerical_tup = ('Numerical', pip_num, num_feature)

# Instantiating the ColumnTransformer

col_transformer = ColumnTransformer([numerical_tup, categorical_tup], verbose_feature_names_out=False)
col_transformer

X_train_processed = col_transformer.fit_transform(X_train)
X_test_processed = col_transformer.transform(X_test)

# %%
def utils_nn_config(model):
    lst_layers = []
    if "Sequential" in str(model): #-> Sequential doesn't show the input layer
        layer = model.layers[0]
        lst_layers.append({"name":"input", "in":int(layer.input.shape[-1]), "neurons":0,
                           "out":int(layer.input.shape[-1]), "activation":None,
                           "params":0, "bias":0})
    for layer in model.layers:
        try:
            dic_layer = {"name":layer.name, "in":int(layer.input.shape[-1]), "neurons":layer.units,
                         "out":int(layer.output.shape[-1]), "activation":layer.get_config()["activation"],
                         "params":layer.get_weights()[0], "bias":layer.get_weights()[1]}
        except:
            dic_layer = {"name":layer.name, "in":int(layer.input.shape[-1]), "neurons":0,
                         "out":int(layer.output.shape[-1]), "activation":None,
                         "params":0, "bias":0}
        lst_layers.append(dic_layer)
    return lst_layers

def visualize_nn(model, description=False, figsize=(10,8)):
    ## get layers info
    lst_layers = utils_nn_config(model)
    layer_sizes = [layer["out"] for layer in lst_layers]

    ## fig setup
    fig = plt.figure(figsize=figsize)
    ax = fig.gca()
    ax.set(title=model.name)
    ax.axis('off')
    left, right, bottom, top = 0.1, 0.9, 0.1, 0.9
    x_space = (right-left) / float(len(layer_sizes)-1)
    y_space = (top-bottom) / float(max(layer_sizes))
    p = 0.025

    ## nodes
    for i,n in enumerate(layer_sizes):
        top_on_layer = y_space*(n-1)/2.0 + (top+bottom)/2.0
        layer = lst_layers[i]
        color = "green" if i in [0, len(layer_sizes)-1] else "blue"
        color = "red" if (layer['neurons'] == 0) and (i > 0) else color

        ### add description
        if (description is True):
            d = i if i == 0 else i-0.5
            if layer['activation'] is None:
                plt.text(x=left+d*x_space, y=top, fontsize=10, color=color, s=layer["name"].upper())
            else:
                plt.text(x=left+d*x_space, y=top, fontsize=10, color=color, s=layer["name"].upper())
                plt.text(x=left+d*x_space, y=top-p, fontsize=10, color=color, s=layer['activation']+" (")
                plt.text(x=left+d*x_space, y=top-2*p, fontsize=10, color=color, s="Σ"+str(layer['in'])+"[X*w]+b")
                out = " Y"  if i == len(layer_sizes)-1 else " out"
                plt.text(x=left+d*x_space, y=top-3*p, fontsize=10, color=color, s=") = "+str(layer['neurons'])+out)

        ### circles
        for m in range(n):
            color = "limegreen" if color == "green" else color
            circle = plt.Circle(xy=(left+i*x_space, top_on_layer-m*y_space-4*p), radius=y_space/4.0, color=color, ec='k', zorder=4)
            ax.add_artist(circle)

            ### add text
            if i == 0:
                plt.text(x=left-4*p, y=top_on_layer-m*y_space-4*p, fontsize=10, s=r'$X_{'+str(m+1)+'}$')
            elif i == len(layer_sizes)-1:
                plt.text(x=right+4*p, y=top_on_layer-m*y_space-4*p, fontsize=10, s=r'$y_{'+str(m+1)+'}$')
            else:
                plt.text(x=left+i*x_space+p, y=top_on_layer-m*y_space+(y_space/8.+0.01*y_space)-4*p, fontsize=10, s=r'$H_{'+str(m+1)+'}$')

    ## links
    for i, (n_a, n_b) in enumerate(zip(layer_sizes[:-1], layer_sizes[1:])):
        layer = lst_layers[i+1]
        color = "green" if i == len(layer_sizes)-2 else "blue"
        color = "red" if layer['neurons'] == 0 else color
        layer_top_a = y_space*(n_a-1)/2. + (top+bottom)/2. -4*p
        layer_top_b = y_space*(n_b-1)/2. + (top+bottom)/2. -4*p
        for m in range(n_a):
            for o in range(n_b):
                line = plt.Line2D([i*x_space+left, (i+1)*x_space+left],
                                  [layer_top_a-m*y_space, layer_top_b-o*y_space],
                                  c=color, alpha=0.5)
                if layer['activation'] is None:
                    if o == m:
                        ax.add_artist(line)
                else:
                    ax.add_artist(line)
    plt.show()

# %%
# new libraries
import tensorflow.keras as keras
from keras.models import Sequential
from keras.layers import Dense

# Build your model
model = Sequential()
model.add(Dense(5, input_dim = X_train_processed.shape[1], activation='relu'))
model.add(Dense(10, activation='sigmoid'))
#model.add(Dense(2, activation='sigmoid'))
model.add(Dense(1, activation='sigmoid'))

# One output node with 'sigmoid' activation
model.summary()

# Visualize network
visualize_nn(model)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_9"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_23 (Dense)                │ (None, 5)              │           105 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_24 (Dense)                │ (None, 10)             │            60 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_25 (Dense)                │ (None, 1)              │            11 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 176 (704.00 B)
#  Trainable params: 176 (704.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
# You can use this function to see how your model improves over time
def plot_history(history, metric=None):
  """plot loss and passed metric.  metric is passed as string and must match 'metric'
  argument in the compile step"""
  fig, axes = plt.subplots(2,1, figsize = (5,10))
  axes[0].plot(history.history['loss'], label = "train")
  axes[0].plot(history.history['val_loss'], label='test')
  axes[0].set_title('Loss')
  axes[0].legend()
  if metric:
    axes[1].plot(history.history[metric], label = 'train')
    axes[1].plot(history.history['val_' + metric], label = 'test')
    axes[1].set_title(metric)
    axes[1].legend()

  plt.show()

# %%
from tensorflow.keras.metrics import Precision, Recall
# Compile your model, set metrics = ['acc']
model.compile(loss='bce', optimizer='adam', metrics=['accuracy', Precision(), Recall()])

# %%
# fit your model
history = model.fit(X_train_processed, y_train,
          validation_data=(X_test_processed, y_test),
          epochs=100)
# Out:
# Epoch 1/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - accuracy: 0.6257 - loss: 0.6793 - precision_4: 0.7089 - recall_4: 0.4509 - val_accuracy: 0.6043 - val_loss: 0.6788 - val_precision_4: 0.6143 - val_recall_4: 0.4778
# Epoch 2/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6795 - loss: 0.6621 - precision_4: 0.6927 - recall_4: 0.5636 - val_accuracy: 0.6364 - val_loss: 0.6665 - val_precision_4: 0.6667 - val_recall_4: 0.4889
# Epoch 3/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7021 - loss: 0.6511 - precision_4: 0.7734 - recall_4: 0.5824 - val_accuracy: 0.6738 - val_loss: 0.6528 - val_precision_4: 0.7101 - val_recall_4: 0.5444
# Epoch 4/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7276 - loss: 0.6366 - precision_4: 0.7552 - recall_4: 0.6328 - val_accuracy: 0.7219 - val_loss: 0.6379 - val_precision_4: 0.7500 - val_recall_4: 0.6333
# Epoch 5/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7385 - loss: 0.6173 - precision_4: 0.7602 - recall_4: 0.6412 - val_accuracy: 0.7433 - val_loss: 0.6205 - val_precision_4: 0.7692 - val_recall_4: 0.6667
# Epoch 6/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7567 - loss: 0.6009 - precision_4: 0.7668 - recall_4: 0.6867 - val_accuracy: 0.7380 - val_loss: 0.6017 - val_precision_4: 0.7595 - val_recall_4: 0.6667
# Epoch 7/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7807 - loss: 0.5832 - precision_4: 0.7759 - recall_4: 0.7623 - val_accuracy: 0.7540 - val_loss: 0.5820 - val_precision_4: 0.7750 - val_recall_4: 0.6889
# Epoch 8/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7896 - loss: 0.5533 - precision_4: 0.7580 - recall_4: 0.7716 - val_accuracy: 0.7647 - val_loss: 0.5614 - val_precision_4: 0.7875 - val_recall_4: 0.7000
# Epoch 9/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7882 - loss: 0.5438 - precision_4: 0.7775 - recall_4: 0.7910 - val_accuracy: 0.7807 - val_loss: 0.5419 - val_precision_4: 0.7882 - val_recall_4: 0.7444
# Epoch 10/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8142 - loss: 0.5241 - precision_4: 0.8182 - recall_4: 0.8066 - val_accuracy: 0.7914 - val_loss: 0.5221 - val_precision_4: 0.7931 - val_recall_4: 0.7667
# Epoch 11/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8086 - loss: 0.5045 - precision_4: 0.8076 - recall_4: 0.7811 - val_accuracy: 0.8128 - val_loss: 0.5032 - val_precision_4: 0.8313 - val_recall_4: 0.7667
# Epoch 12/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8270 - loss: 0.4819 - precision_4: 0.8287 - recall_4: 0.8130 - val_accuracy: 0.8182 - val_loss: 0.4856 - val_precision_4: 0.8415 - val_recall_4: 0.7667
# Epoch 13/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8447 - loss: 0.4537 - precision_4: 0.8459 - recall_4: 0.8161 - val_accuracy: 0.8235 - val_loss: 0.4692 - val_precision_4: 0.8519 - val_recall_4: 0.7667
# Epoch 14/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8205 - loss: 0.4570 - precision_4: 0.7903 - recall_4: 0.8181 - val_accuracy: 0.8289 - val_loss: 0.4547 - val_precision_4: 0.8537 - val_recall_4: 0.7778
# Epoch 15/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8519 - loss: 0.4215 - precision_4: 0.8605 - recall_4: 0.8416 - val_accuracy: 0.8342 - val_loss: 0.4397 - val_precision_4: 0.8471 - val_recall_4: 0.8000
# Epoch 16/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8417 - loss: 0.4448 - precision_4: 0.8468 - recall_4: 0.8098 - val_accuracy: 0.8396 - val_loss: 0.4274 - val_precision_4: 0.8571 - val_recall_4: 0.8000
# Epoch 17/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8751 - loss: 0.4015 - precision_4: 0.8670 - recall_4: 0.8676 - val_accuracy: 0.8396 - val_loss: 0.4159 - val_precision_4: 0.8571 - val_recall_4: 0.8000
# Epoch 18/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8590 - loss: 0.4089 - precision_4: 0.8617 - recall_4: 0.8531 - val_accuracy: 0.8396 - val_loss: 0.4046 - val_precision_4: 0.8571 - val_recall_4: 0.8000
# Epoch 19/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8316 - loss: 0.4243 - precision_4: 0.8208 - recall_4: 0.8235 - val_accuracy: 0.8396 - val_loss: 0.3960 - val_precision_4: 0.8571 - val_recall_4: 0.8000
# Epoch 20/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8717 - loss: 0.3725 - precision_4: 0.8531 - recall_4: 0.8746 - val_accuracy: 0.8449 - val_loss: 0.3868 - val_precision_4: 0.8588 - val_recall_4: 0.8111
# Epoch 21/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8532 - loss: 0.3797 - precision_4: 0.8486 - recall_4: 0.8258 - val_accuracy: 0.8556 - val_loss: 0.3783 - val_precision_4: 0.8621 - val_recall_4: 0.8333
# Epoch 22/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8665 - loss: 0.3631 - precision_4: 0.8858 - recall_4: 0.8425 - val_accuracy: 0.8556 - val_loss: 0.3709 - val_precision_4: 0.8621 - val_recall_4: 0.8333
# Epoch 23/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8662 - loss: 0.3682 - precision_4: 0.8951 - recall_4: 0.8384 - val_accuracy: 0.8556 - val_loss: 0.3651 - val_precision_4: 0.8621 - val_recall_4: 0.8333
# Epoch 24/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8584 - loss: 0.3744 - precision_4: 0.8573 - recall_4: 0.8464 - val_accuracy: 0.8556 - val_loss: 0.3599 - val_precision_4: 0.8621 - val_recall_4: 0.8333
# Epoch 25/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8514 - loss: 0.3767 - precision_4: 0.8577 - recall_4: 0.8448 - val_accuracy: 0.8610 - val_loss: 0.3560 - val_precision_4: 0.8721 - val_recall_4: 0.8333
# Epoch 26/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8481 - loss: 0.3754 - precision_4: 0.8682 - recall_4: 0.8043 - val_accuracy: 0.8610 - val_loss: 0.3508 - val_precision_4: 0.8721 - val_recall_4: 0.8333
# Epoch 27/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8640 - loss: 0.3604 - precision_4: 0.8659 - recall_4: 0.8491 - val_accuracy: 0.8610 - val_loss: 0.3467 - val_precision_4: 0.8721 - val_recall_4: 0.8333
# Epoch 28/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8684 - loss: 0.3461 - precision_4: 0.8849 - recall_4: 0.8513 - val_accuracy: 0.8610 - val_loss: 0.3431 - val_precision_4: 0.8721 - val_recall_4: 0.8333
# Epoch 29/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8645 - loss: 0.3452 - precision_4: 0.8739 - recall_4: 0.8488 - val_accuracy: 0.8556 - val_loss: 0.3401 - val_precision_4: 0.8706 - val_recall_4: 0.8222
# Epoch 30/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8842 - loss: 0.3297 - precision_4: 0.8810 - recall_4: 0.8817 - val_accuracy: 0.8556 - val_loss: 0.3381 - val_precision_4: 0.8706 - val_recall_4: 0.8222
# Epoch 31/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8405 - loss: 0.3753 - precision_4: 0.8256 - recall_4: 0.8253 - val_accuracy: 0.8610 - val_loss: 0.3363 - val_precision_4: 0.8810 - val_recall_4: 0.8222
# Epoch 32/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8521 - loss: 0.3676 - precision_4: 0.8410 - recall_4: 0.8479 - val_accuracy: 0.8663 - val_loss: 0.3321 - val_precision_4: 0.8824 - val_recall_4: 0.8333
# Epoch 33/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8478 - loss: 0.3724 - precision_4: 0.8313 - recall_4: 0.8495 - val_accuracy: 0.8610 - val_loss: 0.3298 - val_precision_4: 0.8721 - val_recall_4: 0.8333
# Epoch 34/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8671 - loss: 0.3198 - precision_4: 0.8661 - recall_4: 0.8616 - val_accuracy: 0.8610 - val_loss: 0.3272 - val_precision_4: 0.8721 - val_recall_4: 0.8333
# Epoch 35/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8560 - loss: 0.3506 - precision_4: 0.8635 - recall_4: 0.8338 - val_accuracy: 0.8556 - val_loss: 0.3258 - val_precision_4: 0.8706 - val_recall_4: 0.8222
# Epoch 36/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8417 - loss: 0.3882 - precision_4: 0.8187 - recall_4: 0.8383 - val_accuracy: 0.8610 - val_loss: 0.3253 - val_precision_4: 0.8810 - val_recall_4: 0.8222
# Epoch 37/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8432 - loss: 0.3763 - precision_4: 0.8496 - recall_4: 0.8278 - val_accuracy: 0.8610 - val_loss: 0.3223 - val_precision_4: 0.8810 - val_recall_4: 0.8222
# Epoch 38/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8480 - loss: 0.3653 - precision_4: 0.8557 - recall_4: 0.8288 - val_accuracy: 0.8610 - val_loss: 0.3217 - val_precision_4: 0.8810 - val_recall_4: 0.8222
# Epoch 39/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8494 - loss: 0.3653 - precision_4: 0.8416 - recall_4: 0.8483 - val_accuracy: 0.8610 - val_loss: 0.3210 - val_precision_4: 0.8810 - val_recall_4: 0.8222
# Epoch 40/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8634 - loss: 0.3534 - precision_4: 0.8481 - recall_4: 0.8646 - val_accuracy: 0.8610 - val_loss: 0.3191 - val_precision_4: 0.8810 - val_recall_4: 0.8222
# Epoch 41/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8384 - loss: 0.3736 - precision_4: 0.8150 - recall_4: 0.8354 - val_accuracy: 0.8610 - val_loss: 0.3173 - val_precision_4: 0.8810 - val_recall_4: 0.8222
# Epoch 42/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8586 - loss: 0.3552 - precision_4: 0.8532 - recall_4: 0.8684 - val_accuracy: 0.8610 - val_loss: 0.3165 - val_precision_4: 0.8810 - val_recall_4: 0.8222
# Epoch 43/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8742 - loss: 0.3351 - precision_4: 0.8287 - recall_4: 0.9074 - val_accuracy: 0.8556 - val_loss: 0.3181 - val_precision_4: 0.8795 - val_recall_4: 0.8111
# Epoch 44/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8359 - loss: 0.3668 - precision_4: 0.8171 - recall_4: 0.8496 - val_accuracy: 0.8717 - val_loss: 0.3152 - val_precision_4: 0.8837 - val_recall_4: 0.8444
# Epoch 45/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8653 - loss: 0.3273 - precision_4: 0.8575 - recall_4: 0.8764 - val_accuracy: 0.8717 - val_loss: 0.3136 - val_precision_4: 0.8837 - val_recall_4: 0.8444
# Epoch 46/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8444 - loss: 0.3742 - precision_4: 0.8494 - recall_4: 0.8289 - val_accuracy: 0.8717 - val_loss: 0.3135 - val_precision_4: 0.8837 - val_recall_4: 0.8444
# Epoch 47/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8506 - loss: 0.3473 - precision_4: 0.8330 - recall_4: 0.8546 - val_accuracy: 0.8717 - val_loss: 0.3135 - val_precision_4: 0.8837 - val_recall_4: 0.8444
# Epoch 48/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8701 - loss: 0.3260 - precision_4: 0.8586 - recall_4: 0.8694 - val_accuracy: 0.8717 - val_loss: 0.3134 - val_precision_4: 0.8837 - val_recall_4: 0.8444
# Epoch 49/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8584 - loss: 0.3435 - precision_4: 0.8423 - recall_4: 0.8570 - val_accuracy: 0.8717 - val_loss: 0.3125 - val_precision_4: 0.8837 - val_recall_4: 0.8444
# Epoch 50/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8442 - loss: 0.3684 - precision_4: 0.8043 - recall_4: 0.8402 - val_accuracy: 0.8717 - val_loss: 0.3120 - val_precision_4: 0.8837 - val_recall_4: 0.8444
# Epoch 51/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8755 - loss: 0.3252 - precision_4: 0.8602 - recall_4: 0.8834 - val_accuracy: 0.8717 - val_loss: 0.3110 - val_precision_4: 0.8837 - val_recall_4: 0.8444
# Epoch 52/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8752 - loss: 0.3213 - precision_4: 0.8590 - recall_4: 0.8850 - val_accuracy: 0.8717 - val_loss: 0.3119 - val_precision_4: 0.8837 - val_recall_4: 0.8444
# Epoch 53/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8432 - loss: 0.3713 - precision_4: 0.8237 - recall_4: 0.8300 - val_accuracy: 0.8717 - val_loss: 0.3131 - val_precision_4: 0.8837 - val_recall_4: 0.8444
# Epoch 54/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8749 - loss: 0.3218 - precision_4: 0.8585 - recall_4: 0.8624 - val_accuracy: 0.8717 - val_loss: 0.3116 - val_precision_4: 0.8837 - val_recall_4: 0.8444
# Epoch 55/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8751 - loss: 0.3238 - precision_4: 0.8919 - recall_4: 0.8671 - val_accuracy: 0.8770 - val_loss: 0.3090 - val_precision_4: 0.8851 - val_recall_4: 0.8556
# Epoch 56/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8447 - loss: 0.3650 - precision_4: 0.8398 - recall_4: 0.8636 - val_accuracy: 0.8717 - val_loss: 0.3109 - val_precision_4: 0.8837 - val_recall_4: 0.8444
# Epoch 57/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8511 - loss: 0.3492 - precision_4: 0.8416 - recall_4: 0.8528 - val_accuracy: 0.8717 - val_loss: 0.3116 - val_precision_4: 0.8837 - val_recall_4: 0.8444
# Epoch 58/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8711 - loss: 0.3273 - precision_4: 0.8490 - recall_4: 0.8700 - val_accuracy: 0.8717 - val_loss: 0.3118 - val_precision_4: 0.8837 - val_recall_4: 0.8444
# Epoch 59/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8779 - loss: 0.3268 - precision_4: 0.8690 - recall_4: 0.8812 - val_accuracy: 0.8717 - val_loss: 0.3101 - val_precision_4: 0.8837 - val_recall_4: 0.8444
# Epoch 60/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8628 - loss: 0.3285 - precision_4: 0.8607 - recall_4: 0.8618 - val_accuracy: 0.8770 - val_loss: 0.3095 - val_precision_4: 0.8851 - val_recall_4: 0.8556
# Epoch 61/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8629 - loss: 0.3336 - precision_4: 0.8690 - recall_4: 0.8639 - val_accuracy: 0.8824 - val_loss: 0.3082 - val_precision_4: 0.8864 - val_recall_4: 0.8667
# Epoch 62/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8639 - loss: 0.3448 - precision_4: 0.8521 - recall_4: 0.8830 - val_accuracy: 0.8770 - val_loss: 0.3103 - val_precision_4: 0.8851 - val_recall_4: 0.8556
# Epoch 63/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8502 - loss: 0.3431 - precision_4: 0.8259 - recall_4: 0.8610 - val_accuracy: 0.8770 - val_loss: 0.3101 - val_precision_4: 0.8851 - val_recall_4: 0.8556
# Epoch 64/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8525 - loss: 0.3588 - precision_4: 0.8349 - recall_4: 0.8683 - val_accuracy: 0.8770 - val_loss: 0.3101 - val_precision_4: 0.8851 - val_recall_4: 0.8556
# Epoch 65/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8241 - loss: 0.3864 - precision_4: 0.8154 - recall_4: 0.8330 - val_accuracy: 0.8824 - val_loss: 0.3102 - val_precision_4: 0.8864 - val_recall_4: 0.8667
# Epoch 66/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8519 - loss: 0.3564 - precision_4: 0.8333 - recall_4: 0.8498 - val_accuracy: 0.8877 - val_loss: 0.3102 - val_precision_4: 0.8966 - val_recall_4: 0.8667
# Epoch 67/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8706 - loss: 0.3237 - precision_4: 0.8625 - recall_4: 0.8696 - val_accuracy: 0.8877 - val_loss: 0.3111 - val_precision_4: 0.8966 - val_recall_4: 0.8667
# Epoch 68/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8659 - loss: 0.3259 - precision_4: 0.8267 - recall_4: 0.8980 - val_accuracy: 0.8877 - val_loss: 0.3113 - val_precision_4: 0.8966 - val_recall_4: 0.8667
# Epoch 69/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8736 - loss: 0.3124 - precision_4: 0.8525 - recall_4: 0.8864 - val_accuracy: 0.8877 - val_loss: 0.3107 - val_precision_4: 0.8966 - val_recall_4: 0.8667
# Epoch 70/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8527 - loss: 0.3585 - precision_4: 0.8499 - recall_4: 0.8605 - val_accuracy: 0.8877 - val_loss: 0.3102 - val_precision_4: 0.8966 - val_recall_4: 0.8667
# Epoch 71/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8602 - loss: 0.3445 - precision_4: 0.8425 - recall_4: 0.8699 - val_accuracy: 0.8877 - val_loss: 0.3108 - val_precision_4: 0.8966 - val_recall_4: 0.8667
# Epoch 72/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8530 - loss: 0.3577 - precision_4: 0.8373 - recall_4: 0.8544 - val_accuracy: 0.8877 - val_loss: 0.3105 - val_precision_4: 0.8966 - val_recall_4: 0.8667
# Epoch 73/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8781 - loss: 0.3093 - precision_4: 0.8787 - recall_4: 0.8711 - val_accuracy: 0.8877 - val_loss: 0.3100 - val_precision_4: 0.8966 - val_recall_4: 0.8667
# Epoch 74/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8720 - loss: 0.3142 - precision_4: 0.8454 - recall_4: 0.8879 - val_accuracy: 0.8877 - val_loss: 0.3122 - val_precision_4: 0.8966 - val_recall_4: 0.8667
# Epoch 75/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8670 - loss: 0.3339 - precision_4: 0.8549 - recall_4: 0.8808 - val_accuracy: 0.8824 - val_loss: 0.3099 - val_precision_4: 0.8864 - val_recall_4: 0.8667
# Epoch 76/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8526 - loss: 0.3364 - precision_4: 0.8265 - recall_4: 0.8764 - val_accuracy: 0.8877 - val_loss: 0.3113 - val_precision_4: 0.8966 - val_recall_4: 0.8667
# Epoch 77/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8496 - loss: 0.3443 - precision_4: 0.8289 - recall_4: 0.8685 - val_accuracy: 0.8877 - val_loss: 0.3111 - val_precision_4: 0.8966 - val_recall_4: 0.8667
# Epoch 78/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8626 - loss: 0.3266 - precision_4: 0.8230 - recall_4: 0.8895 - val_accuracy: 0.8824 - val_loss: 0.3106 - val_precision_4: 0.8864 - val_recall_4: 0.8667
# Epoch 79/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8597 - loss: 0.3409 - precision_4: 0.8727 - recall_4: 0.8451 - val_accuracy: 0.8824 - val_loss: 0.3103 - val_precision_4: 0.8864 - val_recall_4: 0.8667
# Epoch 80/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8652 - loss: 0.3407 - precision_4: 0.8454 - recall_4: 0.8787 - val_accuracy: 0.8877 - val_loss: 0.3117 - val_precision_4: 0.8966 - val_recall_4: 0.8667
# Epoch 81/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8496 - loss: 0.3403 - precision_4: 0.8116 - recall_4: 0.8677 - val_accuracy: 0.8877 - val_loss: 0.3134 - val_precision_4: 0.8966 - val_recall_4: 0.8667
# Epoch 82/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8437 - loss: 0.3457 - precision_4: 0.8170 - recall_4: 0.8614 - val_accuracy: 0.8877 - val_loss: 0.3122 - val_precision_4: 0.8966 - val_recall_4: 0.8667
# Epoch 83/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8457 - loss: 0.3353 - precision_4: 0.8174 - recall_4: 0.8550 - val_accuracy: 0.8824 - val_loss: 0.3106 - val_precision_4: 0.8864 - val_recall_4: 0.8667
# Epoch 84/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8867 - loss: 0.3039 - precision_4: 0.8815 - recall_4: 0.8891 - val_accuracy: 0.8824 - val_loss: 0.3112 - val_precision_4: 0.8864 - val_recall_4: 0.8667
# Epoch 85/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8741 - loss: 0.3198 - precision_4: 0.8546 - recall_4: 0.8860 - val_accuracy: 0.8877 - val_loss: 0.3130 - val_precision_4: 0.8966 - val_recall_4: 0.8667
# Epoch 86/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8730 - loss: 0.3224 - precision_4: 0.8585 - recall_4: 0.8902 - val_accuracy: 0.8877 - val_loss: 0.3128 - val_precision_4: 0.8966 - val_recall_4: 0.8667
# Epoch 87/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8955 - loss: 0.2815 - precision_4: 0.8717 - recall_4: 0.9005 - val_accuracy: 0.8877 - val_loss: 0.3118 - val_precision_4: 0.8966 - val_recall_4: 0.8667
# Epoch 88/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8659 - loss: 0.3284 - precision_4: 0.8332 - recall_4: 0.8776 - val_accuracy: 0.8877 - val_loss: 0.3128 - val_precision_4: 0.8966 - val_recall_4: 0.8667
# Epoch 89/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8564 - loss: 0.3386 - precision_4: 0.8155 - recall_4: 0.8777 - val_accuracy: 0.8877 - val_loss: 0.3155 - val_precision_4: 0.8966 - val_recall_4: 0.8667
# Epoch 90/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8741 - loss: 0.3083 - precision_4: 0.8786 - recall_4: 0.8711 - val_accuracy: 0.8877 - val_loss: 0.3125 - val_precision_4: 0.8966 - val_recall_4: 0.8667
# Epoch 91/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8788 - loss: 0.2985 - precision_4: 0.8858 - recall_4: 0.8651 - val_accuracy: 0.8824 - val_loss: 0.3120 - val_precision_4: 0.8864 - val_recall_4: 0.8667
# Epoch 92/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8824 - loss: 0.3034 - precision_4: 0.8656 - recall_4: 0.8865 - val_accuracy: 0.8877 - val_loss: 0.3146 - val_precision_4: 0.8966 - val_recall_4: 0.8667
# Epoch 93/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8700 - loss: 0.3111 - precision_4: 0.8425 - recall_4: 0.8859 - val_accuracy: 0.8877 - val_loss: 0.3144 - val_precision_4: 0.8966 - val_recall_4: 0.8667
# Epoch 94/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8661 - loss: 0.3402 - precision_4: 0.8522 - recall_4: 0.8633 - val_accuracy: 0.8877 - val_loss: 0.3145 - val_precision_4: 0.8966 - val_recall_4: 0.8667
# Epoch 95/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8722 - loss: 0.3380 - precision_4: 0.8712 - recall_4: 0.8736 - val_accuracy: 0.8877 - val_loss: 0.3148 - val_precision_4: 0.8966 - val_recall_4: 0.8667
# Epoch 96/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8711 - loss: 0.3303 - precision_4: 0.8813 - recall_4: 0.8510 - val_accuracy: 0.8877 - val_loss: 0.3158 - val_precision_4: 0.8966 - val_recall_4: 0.8667
# Epoch 97/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8833 - loss: 0.2932 - precision_4: 0.8830 - recall_4: 0.8798 - val_accuracy: 0.8877 - val_loss: 0.3167 - val_precision_4: 0.8966 - val_recall_4: 0.8667
# Epoch 98/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8565 - loss: 0.3258 - precision_4: 0.8486 - recall_4: 0.8595 - val_accuracy: 0.8877 - val_loss: 0.3168 - val_precision_4: 0.8966 - val_recall_4: 0.8667
# Epoch 99/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8748 - loss: 0.3048 - precision_4: 0.8625 - recall_4: 0.8845 - val_accuracy: 0.8877 - val_loss: 0.3159 - val_precision_4: 0.8966 - val_recall_4: 0.8667
# Epoch 100/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8803 - loss: 0.2943 - precision_4: 0.8525 - recall_4: 0.8913 - val_accuracy: 0.8824 - val_loss: 0.3195 - val_precision_4: 0.8953 - val_recall_4: 0.8556

# %%
# See how your model is doing
plot_history(history, metric='accuracy')

# %%
test_preds = np.rint(model.predict(X_test_processed))
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step

# %%
from sklearn.metrics import mean_squared_error, classification_report, \
ConfusionMatrixDisplay
print(classification_report(y_test, test_preds))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.91      0.89        97
#            1       0.90      0.86      0.88        90
#
#     accuracy                           0.88       187
#    macro avg       0.88      0.88      0.88       187
# weighted avg       0.88      0.88      0.88       187

# %%
ConfusionMatrixDisplay.from_predictions(y_test, test_preds)
