# %% [markdown]
# # TD 1

# %%
import pandas as pd
import numpy as np

# %%
path = 'titanic_dirty.csv'

# %%
df = pd.read_csv(path)

# %%
df.head(8) #permet d afficger les 8 premieres lignes (5par defaut)
# Out:
#    Unnamed: 0  PassengerId  Survived  Pclass  \
# 0           0            1         0       3
# 1           1            2         1       1
# 2           2            3         1       3
# 3           3            4         1       1
# 4           4            5         0       3
# 5           5            6         0       3
# 6           6            7         0       1
# 7           7            8         0       3
#
#                                                 Name     Sex   Age SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0     1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0     1
# 2                             Heikkinen, Miss. Laina  female  26.0     0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0     1
# 4                           Allen, Mr. William Henry    male  35.0     0
# 5                                   Moran, Mr. James    male   NaN     0
# 6                            McCarthy, Mr. Timothy J    male  54.0     0
# 7                     Palsson, Master. Gosta Leonard    male   2.0     3
#
#    Parch            Ticket    Fare Cabin Embarked
# 0      0         A/5 21171   $7.25   NaN        S
# 1      0          PC 17599  $71.28   C85        C
# 2      0  STON/O2. 3101282   $7.93   NaN        S
# 3      0            113803  $53.10  C123        S
# 4      0            373450   $8.05   NaN        S
# 5      0            330877   $8.46   NaN        Q
# 6      0             17463  $51.86   E46        S
# 7      1            349909  $21.08   NaN        S

# %%
df.tail() #affiche les 5 dernieres
# Out:
#      Unnamed: 0  PassengerId  Survived  Pclass  \
# 901         622          623         1       3
# 902          77           78         0       3
# 903         715          716         0       3
# 904         623          624         0       3
# 905         888          889         0       3
#
#                                            Name     Sex   Age SibSp  Parch  \
# 901                            Nakid, Mr. Sahid    male  20.0     1      1
# 902                    Moutal, Mr. Rahamin Haim    male   NaN     0      0
# 903  Soholt, Mr. Peter Andreas Lauritz Andersen    male  19.0     0      0
# 904                 Hansen, Mr. Henry Damsgaard    male  21.0     0      0
# 905    Johnston, Miss. Catherine Helen "Carrie"  female   NaN     1      2
#
#          Ticket    Fare  Cabin Embarked
# 901        2653  $15.74    NaN        C
# 902      374746   $8.05    NaN        S
# 903      348124   $7.65  F G73        S
# 904      350029   $7.85    NaN        S
# 905  W./C. 6607  $23.45    NaN        S

# %%
df.info() #donne les types...
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 906 entries, 0 to 905
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   906 non-null    int64
#  1   PassengerId  906 non-null    int64
#  2   Survived     906 non-null    int64
#  3   Pclass       906 non-null    int64
#  4   Name         906 non-null    str
#  5   Sex          906 non-null    str
#  6   Age          723 non-null    float64
#  7   SibSp        906 non-null    str
#  8   Parch        906 non-null    int64
#  9   Ticket       906 non-null    str
#  10  Fare         906 non-null    str
#  11  Cabin        207 non-null    str
#  12  Embarked     904 non-null    str
# dtypes: float64(1), int64(5), str(7)
# memory usage: 92.1 KB

# %%
df['Fare'].value_counts() #accede a la colonne Fare et compte combien de fois les valeurs sont repeté
# Out:
# Fare
# $8.05     45
# $13.00    42
# $7.90     38
# $7.75     35
# $26.00    31
#           ..
# $14.11     1
# $50.50     1
# $5.00      1
# $9.85      1
# $10.52     1
# Name: count, Length: 234, dtype: int64

# %%
df['Fare']= df['Fare'].str.replace('$', '') #on remplace les $ par rien

# %%
df['Fare']= df['Fare'].astype(float) #change le type en flaot

# %%
df= df.drop(columns= ['Unnamed: 0']) #on la retire parce quelle est vraiment inutile

# %%
df.rename(columns= {'SibSp' :'Siblings or Spouses'}) #permet de modifier le nom
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 901          623         1       3
# 902           78         0       3
# 903          716         0       3
# 904          624         0       3
# 905          889         0       3
#
#                                                   Name     Sex   Age  \
# 0                              Braund, Mr. Owen Harris    male  22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                               Heikkinen, Miss. Laina  female  26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                             Allen, Mr. William Henry    male  35.0
# ..                                                 ...     ...   ...
# 901                                   Nakid, Mr. Sahid    male  20.0
# 902                           Moutal, Mr. Rahamin Haim    male   NaN
# 903         Soholt, Mr. Peter Andreas Lauritz Andersen    male  19.0
# 904                        Hansen, Mr. Henry Damsgaard    male  21.0
# 905           Johnston, Miss. Catherine Helen "Carrie"  female   NaN
#
#     Siblings or Spouses  Parch            Ticket   Fare  Cabin Embarked
# 0                     1      0         A/5 21171   7.25    NaN        S
# 1                     1      0          PC 17599  71.28    C85        C
# 2                     0      0  STON/O2. 3101282   7.93    NaN        S
# 3                     1      0            113803  53.10   C123        S
# 4                     0      0            373450   8.05    NaN        S
# ..                  ...    ...               ...    ...    ...      ...
# 901                   1      1              2653  15.74    NaN        C
# 902                   0      0            374746   8.05    NaN        S
# 903                   0      0            348124   7.65  F G73        S
# 904                   0      0            350029   7.85    NaN        S
# 905                   1      2        W./C. 6607  23.45    NaN        S
#
# [906 rows x 12 columns]

# %%
df.rename(columns= {'Parch' :'Parents or Children'})
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 901          623         1       3
# 902           78         0       3
# 903          716         0       3
# 904          624         0       3
# 905          889         0       3
#
#                                                   Name     Sex   Age SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0     1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0     1
# 2                               Heikkinen, Miss. Laina  female  26.0     0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0     1
# 4                             Allen, Mr. William Henry    male  35.0     0
# ..                                                 ...     ...   ...   ...
# 901                                   Nakid, Mr. Sahid    male  20.0     1
# 902                           Moutal, Mr. Rahamin Haim    male   NaN     0
# 903         Soholt, Mr. Peter Andreas Lauritz Andersen    male  19.0     0
# 904                        Hansen, Mr. Henry Damsgaard    male  21.0     0
# 905           Johnston, Miss. Catherine Helen "Carrie"  female   NaN     1
#
#      Parents or Children            Ticket   Fare  Cabin Embarked
# 0                      0         A/5 21171   7.25    NaN        S
# 1                      0          PC 17599  71.28    C85        C
# 2                      0  STON/O2. 3101282   7.93    NaN        S
# 3                      0            113803  53.10   C123        S
# 4                      0            373450   8.05    NaN        S
# ..                   ...               ...    ...    ...      ...
# 901                    1              2653  15.74    NaN        C
# 902                    0            374746   8.05    NaN        S
# 903                    0            348124   7.65  F G73        S
# 904                    0            350029   7.85    NaN        S
# 905                    2        W./C. 6607  23.45    NaN        S
#
# [906 rows x 12 columns]

# %%
df.duplicated() #nous permet de voir si des colonnes sont dubliqué True = cest dubliqué
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 901     True
# 902     True
# 903     True
# 904     True
# 905     True
# Length: 906, dtype: bool

# %%
df = df.drop_duplicates() #permet de retirer les coolonnes suprimé

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.nunique() #regarde les nombres uniques (different des autres lignes) les noms/passegerId par exemple sont tous unique (on peut sen servir comme des indices)
# Out:
# PassengerId    891
# Survived         2
# Pclass           3
# Name           891
# Sex              3
# Age             88
# SibSp            8
# Parch            7
# Ticket         681
# Fare           234
# Cabin          147
# Embarked         4
# dtype: int64

# %%
df.set_index('PassengerId', inplace=True) #on va utiliser les id qui sont unique comme indice

# %%
df.drop(columns=['Name'], inplace=True) #on a pas besoin des noms car 1 id = 1 noms

# %%
df.isna() #regarde si il y a des Nane (des infos vide) meme chose que isnul
# Out:
#              Survived  Pclass    Sex    Age  SibSp  Parch  Ticket   Fare  \
# PassengerId
# 1               False   False  False  False  False  False   False  False
# 2               False   False  False  False  False  False   False  False
# 3               False   False  False  False  False  False   False  False
# 4               False   False  False  False  False  False   False  False
# 5               False   False  False  False  False  False   False  False
# ...               ...     ...    ...    ...    ...    ...     ...    ...
# 887             False   False  False  False  False  False   False  False
# 888             False   False  False  False  False  False   False  False
# 889             False   False  False   True  False  False   False  False
# 890             False   False  False  False  False  False   False  False
# 891             False   False  False  False  False  False   False  False
#
#              Cabin  Embarked
# PassengerId
# 1             True     False
# 2            False     False
# 3             True     False
# 4            False     False
# 5             True     False
# ...            ...       ...
# 887           True     False
# 888          False     False
# 889           True     False
# 890          False     False
# 891           True     False
#
# [891 rows x 10 columns]

# %%
df.isna().sum() #nous permet de voir ou sont les nane
# Out:
# Survived      0
# Pclass        0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Ticket        0
# Fare          0
# Cabin       687
# Embarked      2
# dtype: int64

# %%
import missingno as msno
msno.matrix(df)
# Out:
# <Axes: >

# %%
#comment resoudre les Nane
#exemple pas correcte
df['Age'].fillna(df['Age'].median(), inplace = True) # ou .mean() pour la moyenne
# Out:
# C:\Users\theoh\AppData\Local\Temp\ipykernel_8600\2827869062.py:3: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   df['Age'].fillna(df['Age'].median(), inplace = True) # ou .mean() pour la moyenne
# PassengerId
# 1      22.0
# 2      38.0
# 3      26.0
# 4      35.0
# 5      35.0
#        ...
# 887    27.0
# 888    19.0
# 889    28.0
# 890    26.0
# 891    32.0
# Name: Age, Length: 891, dtype: float64

# %%
df.loc[50] #nous permet d'afficher la ligne 50
# Out:
# Survived         0
# Pclass           3
# Sex         female
# Age           18.0
# SibSp            1
# Parch            0
# Ticket      349237
# Fare          17.8
# Cabin          NaN
# Embarked         S
# Name: 50, dtype: object

# %%
df.loc[50,'Sex'] #nous permet de savoir la 50eme ligne colomne sex
# Out:
# 'female'

# %%
(df['Sex'] == "male").sum() #donne le nombre d homme
# Out:
# np.int64(574)
