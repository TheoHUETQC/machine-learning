# %% [markdown]
# # TD 1

# %%
import pandas as pd
import numpy as np

# %%
path = '/content/titanic_dirty.csv'

# %%
df = pd.read_csv(path)

# %%
df.head(8) #permet d afficger les 8 premieres lignes (5par defaut)
# Out:
#    Unnamed: 0  PassengerId  Survived  Pclass  \
# 0           0            1         0       3
# 1           1            2         1       1
# 2           2            3         1       3
# 3           3            4         1       1
# 4           4            5         0       3
# 5           5            6         0       3
# 6           6            7         0       1
# 7           7            8         0       3
#
#                                                 Name     Sex   Age SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0     1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0     1
# 2                             Heikkinen, Miss. Laina  female  26.0     0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0     1
# 4                           Allen, Mr. William Henry    male  35.0     0
# 5                                   Moran, Mr. James    male   NaN     0
# ...

# %%
df.tail() #affiche les 5 dernieres
# Out:
#      Unnamed: 0  PassengerId  Survived  Pclass  \
# 901         622          623         1       3
# 902          77           78         0       3
# 903         715          716         0       3
# 904         623          624         0       3
# 905         888          889         0       3
#
#                                            Name     Sex   Age SibSp  Parch  \
# 901                            Nakid, Mr. Sahid    male  20.0     1      1
# 902                    Moutal, Mr. Rahamin Haim    male   NaN     0      0
# 903  Soholt, Mr. Peter Andreas Lauritz Andersen    male  19.0     0      0
# 904                 Hansen, Mr. Henry Damsgaard    male  21.0     0      0
# 905    Johnston, Miss. Catherine Helen "Carrie"  female   NaN     1      2
#
#          Ticket    Fare  Cabin Embarked
# 901        2653  $15.74    NaN        C
# 902      374746   $8.05    NaN        S
# 903      348124   $7.65  F G73        S
# 904      350029   $7.85    NaN        S
# ...

# %%
df.info() #donne les types...

# %%
df['Fare'] = df['Fare'].Value_counts() #accede a la colonne Fare et compte combien de fois les valeurs sont repeté
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-874151736.py in <cell line: 0>()
# ----> 1 df['Fare'] = df['Fare'].Value_counts() #accede a la colonne Fare et compte combien de fois les valeurs sont repeté
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#    6300
#    6301     @final
#
# AttributeError: 'Series' object has no attribute 'Value_counts'

# %%
df['Fare']= df['Fare'].str.replace('$', '') #on remplace les $ par rien

# %%
df['Fare']= df['Fare'].astype(float) #change le type en flaot

# %%
df= df.drop(columns= ['Unnamed: 0']) #on la retire parce quelle est vraiment inutile

# %%
df.rename(columns= {'SibSp' :'Siblings or Spouses'}) #permet de modifier le nom
# Out:
#      PassengerId  Survived  Pclass     Sex   Age Siblings or Spouses  Parch  \
# 0              1         0       3    male  22.0                   1      0
# 1              2         1       1  female  38.0                   1      0
# 2              3         1       3  female  26.0                   0      0
# 3              4         1       1  female  35.0                   1      0
# 4              5         0       3    male  35.0                   0      0
# ..           ...       ...     ...     ...   ...                 ...    ...
# 901          623         1       3    male  20.0                   1      1
# 902           78         0       3    male  -1.0                   0      0
# 903          716         0       3    male  19.0                   0      0
# 904          624         0       3    male  21.0                   0      0
# 905          889         0       3  female  -1.0                   1      2
#
#                Ticket   Fare  Cabin Embarked
# ...

# %%
df.rename(columns= {'Parch' :'Parents or Children'})
# Out:
#      Unnamed: 0  PassengerId  Survived  Pclass  \
# 0             0            1         0       3
# 1             1            2         1       1
# 2             2            3         1       3
# 3             3            4         1       1
# 4             4            5         0       3
# ..          ...          ...       ...     ...
# 901         622          623         1       3
# 902          77           78         0       3
# 903         715          716         0       3
# 904         623          624         0       3
# 905         888          889         0       3
#
#                                                   Name     Sex   Age SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0     1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0     1
# 2                               Heikkinen, Miss. Laina  female  26.0     0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0     1
# ...

# %%
df.duplicated() #nous permet de voir si des colonnes sont dubliqué True = cest dubliqué
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 901     True
# 902     True
# 903     True
# 904     True
# 905     True
# Length: 906, dtype: bool

# %%
df = df.drop_duplicates() #permet de retirer les coolonnes suprimé

# %%
df.dublicated().sum()

# %%
df.nunique() #regarde les nombres uniques (different des autres lignes) les noms/passegerId par exemple sont tous unique (on peut sen servir comme des indices)

# %%
df.set_index('PassegerId', inplace = True) #on va utiliser les id qui sont unique comme indice
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-4034113844.py in <cell line: 0>()
# ----> 1 df.set_index('PassegerId', inplace = True) #on va utiliser les id qui sont unique comme indice
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    6120
#    6121         if missing:
# -> 6122             raise KeyError(f"None of {missing} are in the columns")
#    6123
#    6124         if inplace:
#
# KeyError: "None of ['PassegerId'] are in the columns"

# %%
df.drop(columns=['Name'], inplace=True) #on a pas besoin des noms car 1 id = 1 noms

# %%
df.isna() #regarde si il y a des Nane (des infos vide) meme chose que isnul

# %%
df.isna().sum() #nous permet de voir ou sont les nane
# Out:
# Unnamed: 0       0
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            183
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          699
# Embarked         2
# dtype: int64

# %%
import missingno as msno
msno.matrix(df)
# Out:
# <Axes: >

# %%
#comment resoudre les Nane
#exemple pas correcte
df['Age'].fillna(-1, inplace=True) #inplace = true corresponda ce que tout les nane soit remplacer par -1

# %%
df.loc[50] #nous permet d'afficher la ligne 50
# Out:
# PassengerId         51
# Survived             0
# Pclass               3
# Sex               male
# Age                7.0
# SibSp                4
# Parch                1
# Ticket         3101295
# Fare             39.69
# Cabin              NaN
# Embarked             S
# Name: 50, dtype: object

# %%
df.loc[50,'Sex'] #nous permet de savoir la 50eme ligne colomne sex
# Out:
# 'male'

# %%
(df['Sex'] == "male").sum() #donne le nombre d homme
# Out:
# np.int64(584)
