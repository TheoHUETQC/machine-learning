# %% [markdown]
# [texte du lien](https://)# SOLUTION - Train Test Split (Practice)

# %%
# import packages
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
# Loading from URL for solution

fpath = "https://docs.google.com/spreadsheets/d/e/2PACX-1vTEH1X54IlixiMYZSnF3JzPN385Ku3drmWP8Ur7YgZYMaNgB8koJcj0KvXoiZMMb8ZZDHbSOla8wthF/pub?output=csv"
df = pd.read_csv(fpath)
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   MedInc       20640 non-null  int64
#  1   HouseAge     20640 non-null  int64
#  2   AveRooms     20640 non-null  float64
#  3   AveBedrms    20640 non-null  float64
#  4   Population   20640 non-null  int64
#  5   AveOccup     20640 non-null  float64
#  6   Latitude     20640 non-null  float64
#  7   Longitude    20640 non-null  float64
#  8   MedHouseVal  20640 non-null  int64
# dtypes: float64(5), int64(4)
# memory usage: 1.4 MB
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  832520        41  6.984127   1.023810         322  2.555556     37.88
# 1  830140        21  6.238137   0.971880        2401  2.109842     37.86
# 2  725740        52  8.288136   1.073446         496  2.802260     37.85
# ...

# %%
# Make X and y
X = df.drop(columns='MedHouseVal') # features
y = df['MedHouseVal'] # target( column predicted)

# %%
# train test split
X_train, X_test, y_train, y_test = train_test_split(X,y)
X_train.head()
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 15589  535900        16  8.116279   1.720930         120  2.790698     32.97
# 6504   251190        37  3.929293   1.035354         850  4.292929     34.08
# 3      564310        52  5.817352   1.073059         558  2.547945     37.85
# 2532   217050        23  5.133333   1.077778         261  2.900000     39.50
# 8549   440000        44  4.644068   1.016949         480  2.711864     33.88
#
#        Longitude
# 15589    -116.67
# 6504     -118.06
# 3        -122.25
# 2532     -122.19
# 8549     -118.35

# %%
# Check data types (or use X_train.dtypes)
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 15480 entries, 15589 to 7364
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   MedInc      15480 non-null  int64
#  1   HouseAge    15480 non-null  int64
#  2   AveRooms    15480 non-null  float64
#  3   AveBedrms   15480 non-null  float64
#  4   Population  15480 non-null  int64
#  5   AveOccup    15480 non-null  float64
#  6   Latitude    15480 non-null  float64
#  7   Longitude   15480 non-null  float64
# dtypes: float64(5), int64(3)
# memory usage: 1.1 MB

# %%
# Check for null values
X_train.isna().sum()
# Out:
# MedInc        0
# HouseAge      0
# AveRooms      0
# AveBedrms     0
# Population    0
# AveOccup      0
# Latitude      0
# Longitude     0
# dtype: int64

# %%
y_train.head()
# Out:
# 15589    193800
# 6504     180500
# 3        341300
# 2532      53000
# 8549     225800
# Name: MedHouseVal, dtype: int64

# %%
# checking shape of X_train
X_train.shape
# Out:
# (15480, 8)

# %%
# checking the shape of X_test
X_test.shape
# Out:
# (5160, 8)

# %% [markdown]
# Finally, compare the shape of the X_train and X_test.
